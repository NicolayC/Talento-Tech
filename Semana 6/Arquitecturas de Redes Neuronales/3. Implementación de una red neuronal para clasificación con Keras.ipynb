# %% [markdown]
# **Importaciones**

# %%
import keras
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Generación de datos sintéticos**

# %%
X, y = make_classification(n_samples=100, n_features=5, n_classes=2)

# %% [markdown]
# **División de los datos**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# **Codificación OneHot de las etiquetas**

# %%
y_train_categorical = keras.utils.to_categorical(y_train)
y_test_categorical = keras.utils.to_categorical(y_test)

# %% [markdown]
# **Creación del modelo**

# %%
model = keras.models.Sequential()

# %% [markdown]
# **Adición de capas al modelo**

# %%
model.add(keras.layers.Dense(10, input_shape=(X_train.shape[1],), activation='relu'))
model.add(keras.layers.Dense(2, activation='softmax'))

# %% [markdown]
# **Compilación del modelo**

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Entrenamiento del modelo**

# %%
model.fit(X_train, y_train_categorical, epochs=10, batch_size=32, validation_data=(X_test, y_test_categorical))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 2s 120ms/step - loss: 0.6364 - accuracy: 0.6000 - val_loss: 0.6832 - val_accuracy: 0.5500
# Epoch 2/10
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6282 - accuracy: 0.6375 - val_loss: 0.6696 - val_accuracy: 0.5000
# Epoch 3/10
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6203 - accuracy: 0.6625 - val_loss: 0.6569 - val_accuracy: 0.5000
# Epoch 4/10
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6124 - accuracy: 0.6750 - val_loss: 0.6450 - val_accuracy: 0.6000
# Epoch 5/10
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6058 - accuracy: 0.7000 - val_loss: 0.6329 - val_accuracy: 0.6000
# Epoch 6/10
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5993 - accuracy: 0.7000 - val_loss: 0.6209 - val_accuracy: 0.6000
# Epoch 7/10
# 3/3 [==============================] - 0s 17ms/step - loss: 0.5922 - accuracy: 0.7250 - val_loss: 0.6096 - val_accuracy: 0.6000
# Epoch 8/10
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5858 - accuracy: 0.7250 - val_loss: 0.5984 - val_accuracy: 0.6000
# Epoch 9/10
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5799 - accuracy: 0.7500 - val_loss: 0.5875 - val_accuracy: 0.6000
# Epoch 10/10
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5742 - accuracy: 0.7375 - val_loss: 0.5772 - val_accuracy: 0.6000

# %% [markdown]
# **Evaluación del modelo**

# %%
loss, accuracy = model.evaluate(X_test, y_test_categorical)
# Out:
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5772 - accuracy: 0.6000

# %% [markdown]
# **Impresión de resultados**

# %%
print(f'Pérdida en el conjunto de prueba: {loss}')
print(f'Precisión en el conjunto de prueba: {accuracy}')
# Out:
# Pérdida en el conjunto de prueba: 0.5771840214729309
# Precisión en el conjunto de prueba: 0.6000000238418579
