# %% [markdown]
# **Importaciones**

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
# !pip install opencv-python-headless

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Carga del clasificador de cascada**

# %%
face_cascade_path = cv2.data.haarcascades + 'haarcascade_frontalcatface.xml'
face_cascade = cv2.CascadeClassifier(face_cascade_path)

# %%
face_cascade_path = cv2.data.haarcascades + 'haarcascade_frontalcatface.xml'
face_cascade = cv2.CascadeClassifier(face_cascade_path)

if face_cascade.empty():
    print("Error: El archivo del clasificador Haar Cascade no se ha cargado correctamente.")
else:
    print("El clasificador Haar Cascade se ha cargado correctamente.")
# Out:
# El clasificador Haar Cascade se ha cargado correctamente.

# %% [markdown]
# **Carga de la imagen**

# %%
ruta_imagen = '/content/drive/My Drive/gato.jpg'

# %%
image = cv2.imread(ruta_imagen)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# **Detección de rostros de gatos**

# %%
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

print(faces)
# Out:
# ()

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Mostrar la imagen con los rostros detectados
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675>

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis('off')
plt.show()
